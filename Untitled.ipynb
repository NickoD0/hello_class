# %%
bee_file = open('new_f.txt')
b_count = 0
for line in bee_file:
    if 'bee' or 'bees' in line:
        b_count +=1
        
print("There are", b_count,"bees in the bee movie script!")
# Out:
# There are 130 bees in the bee movie script!
